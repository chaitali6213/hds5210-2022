# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
#Importing CSV file- CDC Injury Center Drug Overdose Deaths for creating DataFrame 

import pandas as pd

# %%
CDS=pd.read_csv('CDC Injury Center Drug Overdose Deaths.csv')

# %%
CDS
# Out:
#                    State State Abbreviation  \
# 0                Alabama                 AL
# 1                 Alaska                 AK
# 2                Arizona                 AZ
# 3               Arkansas                 AR
# 4             California                 CA
# 5               Colorado                 CO
# 6            Connecticut                 CT
# 7               Delaware                 DE
# 8   District of Columbia                 DC
# 9                Florida                 FL
# 10               Georgia                 GA
# 11                Hawaii                 HI
# 12                 Idaho                 ID
# 13              Illinois                 IL
# 14               Indiana                 IN
# 15                  Iowa                 IA
# 16                Kansas                 KS
# 17              Kentucky                 KY
# 18             Louisiana                 LA
# 19                 Maine                 ME
# ...

# %%
CDS.shape
# Out:
# (51, 24)

# %%
CDS.columns
# Out:
# Index(['State', 'State Abbreviation',
#        '2019 Age-adjusted Rate (per 100,000 population)',
#        '2019 Number of Deaths',
#        '2018 Age-adjusted Rate (per 100,000 population)',
#        '2018 Number of Deaths',
#        '2017 Age-adjusted Rate (per 100,000 population)',
#        '2017 Number of Deaths',
#        '2016 Age-adjusted Rate (per 100,000 population)',
#        '2016 Number of Deaths',
#        '2015 Age-adjusted Rate (per 100,000 population)',
#        '2015 Number of Deaths',
#        '2014 Age-adjusted Rate (per 100,000 population)',
#        '2014 Number of Deaths',
#        '2013 Age-adjusted Rate (per 100,000 population)',
#        '2013 Number of Deaths',
#        '2019 Poverty rate (percent of persons in poverty)',
#        'Gini coefficient of income inequality', 'GDP per capita 2021',
#        'GDP (nominal in millions of USD) 2021',
#        'Urban population as a percentage of the total population in 2010',
# ...

# %%
column_count=len(CDS.columns)

# %%
column_count
# Out:
# 24

# %%
CDS.dtypes
# Out:
# State                                                                object
# State Abbreviation                                                   object
# 2019 Age-adjusted Rate (per 100,000 population)                     float64
# 2019 Number of Deaths                                                 int64
# 2018 Age-adjusted Rate (per 100,000 population)                     float64
# 2018 Number of Deaths                                                 int64
# 2017 Age-adjusted Rate (per 100,000 population)                     float64
# 2017 Number of Deaths                                               float64
# 2016 Age-adjusted Rate (per 100,000 population)                     float64
# 2016 Number of Deaths                                               float64
# 2015 Age-adjusted Rate (per 100,000 population)                     float64
# 2015 Number of Deaths                                               float64
# ...

# %%
#Importing CSV file- Drug Overdose Deaths
#creating DaAframe from that file

import pandas as pd
data=pd.read_csv('DRUG OVERDOSE DEATHS.csv')

# %%
data
# Out:
#       Unnamed: 0       ID                    Date  DateType   Age     Sex  \
# 0              0  14-0273  06/28/2014 12:00:00 AM       1.0   NaN     NaN
# 1              1  13-0102  03/21/2013 12:00:00 AM       0.0  48.0    Male
# 2              2  16-0165  03/13/2016 12:00:00 AM       0.0  30.0  Female
# 3              3  16-0208  03/31/2016 12:00:00 AM       0.0  23.0    Male
# 4              4  13-0052  02/13/2013 12:00:00 AM       0.0  22.0    Male
# ...          ...      ...                     ...       ...   ...     ...
# 5100        5100  15-0466        09-08-2015 00:00       1.0  43.0    Male
# 5101        5101  17-0618  07/22/2017 12:00:00 AM       1.0  21.0    Male
# 5102        5102  18-0646  08/14/2018 12:00:00 AM       0.0  30.0    Male
# 5103        5103  14-0124  03/16/2014 12:00:00 AM       0.0  33.0    Male
# 5104        5104  16-0637  09/15/2016 12:00:00 AM       0.0  33.0    Male
#
#               Race  ResidenceCity ResidenceCounty ResidenceState  ... Tramad  \
# ...

# %%
data.shape
# Out:
# (5105, 42)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Date', 'DateType', 'Age', 'Sex', 'Race',
#        'ResidenceCity', 'ResidenceCounty', 'ResidenceState', 'DeathCity',
#        'DeathCounty', 'Location', 'LocationifOther', 'DescriptionofInjury',
#        'InjuryPlace', 'InjuryCity', 'InjuryCounty', 'InjuryState', 'COD',
#        'OtherSignifican', 'Heroin', 'Cocaine', 'Fentanyl', 'Fentanyl_Analogue',
#        'Oxycodone', 'Oxymorphone', 'Ethanol', 'Hydrocodone', 'Benzodiazepine',
#        'Methadone', 'Amphet', 'Tramad', 'Morphine_NotHeroin', 'Hydromorphone',
#        'Other', 'OpiateNOS', 'AnyOpioid', 'MannerofDeath', 'DeathCityGeo',
#        'ResidenceCityGeo', 'InjuryCityGeo'],
#       dtype='object')

# %%
column_count=len(data.columns)

# %%
column_count
# Out:
# 42

# %%
data.dtypes
# Out:
# Unnamed: 0               int64
# ID                      object
# Date                    object
# DateType               float64
# Age                    float64
# Sex                     object
# Race                    object
# ResidenceCity           object
# ResidenceCounty         object
# ResidenceState          object
# DeathCity               object
# DeathCounty             object
# Location                object
# LocationifOther         object
# DescriptionofInjury     object
# InjuryPlace             object
# InjuryCity              object
# InjuryCounty            object
# InjuryState             object
# COD                     object
# OtherSignifican         object
# Heroin                   int64
# Cocaine                  int64
# Fentanyl                object
# Fentanyl_Analogue        int64
# Oxycodone                int64
# Oxymorphone              int64
# Ethanol                  int64
# Hydrocodone              int64
# Benzodiazepine           int64
# ...

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
#Count of Unique values from the dataset

# %%
CDS['GDP per capita 2021'].unique()
# Out:
# array([ 48475,  69336,  55954,  47629,  83213,  72212,  81712,  80087,
#        219550,  55664,  62833,  61616,  50187,  73226,  61210,  69248,
#         65740,  52001,  54385,  54760,  71833,  88921,  55518,  71391,
#         41796,  58332,  53419,  76730,  60359,  68159,  72288,  51116,
#         92480,  61900,  83402,  62046,  51917,  62331,  64044,  58475,
#         51984,  68582,  59571,  66818,  65061,  56119,  67920,  85852,
#         47833,  61690,  71420])

# %%
CDS['GDP per capita 2021'].value_counts()
# Out:
# 88921     1
# 52001     1
# 92480     1
# 68159     1
# 71420     1
# 76730     1
# 56119     1
# 59571     1
# 61616     1
# 64044     1
# 53419     1
# 65061     1
# 219550    1
# 41796     1
# 61210     1
# 62046     1
# 81712     1
# 72212     1
# 55954     1
# 51984     1
# 47629     1
# 50187     1
# 73226     1
# 66818     1
# 51116     1
# 65740     1
# 62331     1
# 71391     1
# 61690     1
# 54385     1
# 71833     1
# 62833     1
# 55664     1
# 58475     1
# 54760     1
# 85852     1
# 68582     1
# 72288     1
# 55518     1
# 60359     1
# 58332     1
# 48475     1
# 47833     1
# 69336     1
# 80087     1
# 83213     1
# 67920     1
# 51917     1
# 61900     1
# 83402     1
# 69248     1
# Name: GDP per capita 2021, dtype: int64

# %%
CDS = CDS[CDS['State Abbreviation'].isin(['CA','GA','IL','WY','WA','TX','NY','M0'])]
by_state = CDS.groupby('State Abbreviation')

# %%
CDS
# Out:
#          State State Abbreviation  \
# 4   California                 CA
# 10     Georgia                 GA
# 13    Illinois                 IL
# 32    New York                 NY
# 43       Texas                 TX
# 47  Washington                 WA
# 50     Wyoming                 WY
#
#     2019 Age-adjusted Rate (per 100,000 population)  2019 Number of Deaths  \
# 4                                              15.0                   6198
# 10                                             13.1                   1408
# 13                                             21.9                   2790
# 32                                             18.2                   3617
# 43                                             10.8                   3136
# 47                                             15.8                   1259
# 50                                             14.1                     79
#
#     2018 Age-adjusted Rate (per 100,000 population)  2018 Number of Deaths  \
# ...

# %%
CDS['State Abbreviation'].unique()
# Out:
# array(['CA', 'GA', 'IL', 'NY', 'TX', 'WA', 'WY'], dtype=object)

# %%
CDS['State Abbreviation'].value_counts()
# Out:
# GA    1
# WY    1
# CA    1
# TX    1
# IL    1
# NY    1
# WA    1
# Name: State Abbreviation, dtype: int64

# %%
data['Age'].unique()
# Out:
# array([nan, 48., 30., 23., 22., 21., 40., 50., 26., 49., 29., 45., 42.,
#        54., 32., 47., 39., 27., 34., 25., 51., 35., 43., 55., 56., 28.,
#        67., 36., 52., 61., 53., 41., 31., 57., 24., 37., 38., 58., 59.,
#        46., 64., 60., 44., 33., 20., 19., 66., 63., 62., 65., 71., 73.,
#        68., 69., 75., 72., 18., 15., 70., 17., 74., 84., 14., 87., 81.,
#        16.])

# %%
data['Age'].value_counts()
# Out:
# 29.0    152
# 33.0    147
# 44.0    147
# 50.0    145
# 54.0    144
#        ...
# 87.0      1
# 81.0      1
# 84.0      1
# 74.0      1
# 16.0      1
# Name: Age, Length: 65, dtype: int64

# %%
data['Heroin'].sum()
# Out:
# 2529

# %%
data['Heroin'].value_counts()
# Out:
# 0    2576
# 1    2529
# Name: Heroin, dtype: int64

# %%
data["Heroin"].agg(['min','max','mean','median','std','count'])
# Out:
# min          0.000000
# max          1.000000
# mean         0.495397
# median       0.000000
# std          0.500028
# count     5105.000000
# Name: Heroin, dtype: float64

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
data.groupby("Sex").count()
# Out:
#          Unnamed: 0    ID  Date  DateType   Age  Race  ResidenceCity  \
# Sex
# Female         1325  1325  1325      1325  1325  1320           1281
# Male           3773  3773  3772      3772  3773  3768           3647
# Unknown           1     1     1         1     1     1              1
#
#          ResidenceCounty  ResidenceState  DeathCity  ...  Tramad  \
# Sex                                                  ...
# Female              1100             886       1325  ...    1325
# Male                3204            2666       3771  ...    3773
# Unknown                1               1          1  ...       1
#
#          Morphine_NotHeroin  Hydromorphone  Other  OpiateNOS  AnyOpioid  \
# Sex
# Female                 1325           1325    157       1325       1325
# Male                   3773           3773    278       3773       3773
# Unknown                   1              1      0          1          1
#
# ...

# %%
data.groupby("Sex").count().reset_index()
# Out:
#        Sex  Unnamed: 0    ID  Date  DateType   Age  Race  ResidenceCity  \
# 0   Female        1325  1325  1325      1325  1325  1320           1281
# 1     Male        3773  3773  3772      3772  3773  3768           3647
# 2  Unknown           1     1     1         1     1     1              1
#
#    ResidenceCounty  ResidenceState  ...  Tramad  Morphine_NotHeroin  \
# 0             1100             886  ...    1325                1325
# 1             3204            2666  ...    3773                3773
# 2                1               1  ...       1                   1
#
#    Hydromorphone  Other  OpiateNOS  AnyOpioid  MannerofDeath  DeathCityGeo  \
# 0           1325    157       1325       1325           1325          1325
# 1           3773    278       3773       3773           3764          3773
# 2              1      0          1          1              1             1
#
#    ResidenceCityGeo  InjuryCityGeo
# 0              1302           1309
# ...

# %%
data_filter=data["Sex"].str.contains('Male')

# %%
data_filter
# Out:
# 0         NaN
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 5100     True
# 5101     True
# 5102     True
# 5103     True
# 5104     True
# Name: Sex, Length: 5105, dtype: object

# %% [markdown]
# ### 4. Range of Values
#
#  data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
#Plotting from pandas

# %%
#Plotting histogram of 2019 Number of death
CDS['2019 Number of Deaths'].hist()

# %%
# In above histogram - In california state deaths due to drug overdose was more.
# In Wyoming state deaths due to drug abuse was very less.

# %%
#Plotting bar plot state-
import seaborn as sns
sns.barplot(x='State', y='2019 Number of Deaths', data=CDS)

# %%
#In california deaths were more in 2019 year due to drug overdose.
#In wyoming deaths were very less in 2019 due to drug overdose.

# %%
sns.barplot(x='State', y='2014 Number of Deaths', data=CDS)

# %%
#Plotting Scatterplots-
CDS.plot.scatter(x='Population density per km²', y='Population')

# %%
#Plotting histogram of Age From the data 
data['Age'].hist()

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
data['Heroin'].sum()
# Out:
# 2529

# %%
data['Cocaine'].sum()
# Out:
# 1521

# %%
data['Ethanol'].sum()
# Out:
# 1247

# %%
data['Oxycodone'].sum()
# Out:
# 607

# %%
data['Methadone'].sum()
# Out:
# 474

# %%
import pandas as pd
df=pd.DataFrame([2529,1521,1247,607,474],index=['Heroin','Cocaine','Ethanol','Oxycodone','Methadone'])
df.plot(kind='pie',subplots= True, figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3b45951ef0>],
#       dtype=object)

# %%
###According to the data - DRUG OVERDOSE DEATHS-
#The rate of overdose deaths in Connecticut increased from 9.9 per 100,000 residents in 2012 to 28.5 per 100,000
#residents in 2018-a 221 % increase-with the majority occurring among persons aged 35-64 (65.3 %), men (73.9 %).
#Most of the deaths occur due to consuming Heroin, the overall deaths escalated from 5.2 deaths per 100,000 
#residents in 2015 to 21.3 deaths per 100,000 residents in 2018.

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
